# %%
#Task 1 - Fitbit Dataset

1. Read this dataset in pandas , mysql and mongodb 
2. while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql
 ## hint - use csvkit library to automate this task and to load a data in bulk in you mysql 
3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
4 . Find out in this data that how many unique id's we have 
5 . which id is one of the active id that you have in whole dataset 
6 . how many of them have not logged there activity find out in terms of number of ids 
7 . Find out who is the laziest person id that we have in dataset 
8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset 
9. how many person are not a regular person with respect to activity try to find out those 
10 . who is the thired most active person in this dataset find out those in pandas and in sql both . 
11 . who is the 5th most laziest person avilable in dataset find it out 
12 . what is a totla acumulative calories burn for a person find out

# %%
#. 1-Task and 2-Task

# load the data set into mysql work bench automatic insertion entire csv file
# !pip install mysqlclient
import pandas as pd 
mysql_engine = ("mysql://kishor:mysql123@localhost:3306/ineuron") # It will help to connect mysql server as well as database
data=pd.read_csv(r"D:\New folder(2)\FitBit.csv") # It will help to read the csv file
data.to_sql('fitbit1',mysql_engine) # It help to load the data in mysql workbench

# we are connect to mysql server through jupyter notebook
import mysql.connector as connection
mydb = connection.connect(host='localhost',user='kishor',password='mysql123',use_pure=True)
con = mydb.cursor()
con.execute('show databases')
con.fetchall()
# Out:
# [('imp',),
#  ('ineuron',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('uday',)]

# %%
con.execute("use ineuron") # we are select the database

# %%
con.execute("select * from fitbit") # we are the table from the ineuron database

# %%
for i in con.fetchall():# we are trying to read the mysql workbench table into jupyter notebook one by one
    #print(i)

# %%
import pandas as pd
df=pd.read_csv(r"D:\New folder(2)\FitBit.csv") # we trying to read the csv file in jupyter from pandas

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
# here we are inserting entire csv into mongoDB with automation
import pandas as pd
import pymongo
import json

client=pymongo.MongoClient("mongodb+srv://kishore:mongodb@cluster0.4xwrt.mongodb.net/?retryWrites=true&w=majority") # we are connecting to mongoDB server
df_1=pd.read_csv(r"D:\New folder(2)\FitBit.csv") # we are reading csv file in pandas
df_1
data_1=df_1.to_dict(orient='records') # we are trying convert csv into dictionary formate
db=client['mongotest1'] # we are connecting to existing database
db.Fitbit.insert_many(data_1) # we are creating a table in mongoDB and inserting the data

# to read the records in jupyter notebook
db=client['mongotest1'] 
collection=db['Fitbit']
records=collection.find()
for i in records:
    print(i)

# %%
# Task 3
import pandas as pd
df_2=pd.read_csv(r"D:\New folder(2)\FitBit.csv")

# %%
df_2
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
df_2['ActivityDate'] # we are extract the converting date columns
# Out:
# 0       3/25/2016
# 1       3/26/2016
# 2       3/27/2016
# 3       3/28/2016
# 4       3/29/2016
#           ...
# 452    04-08-2016
# 453    04-09-2016
# 454    04-10-2016
# 455    04-11-2016
# 456    04-12-2016
# Name: ActivityDate, Length: 457, dtype: object

# %%
df_2['converted_date']=pd.to_datetime(df_2['ActivityDate'])
df_2
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#     converted_date  converted_month  converted_year  converted_week  \
# 0       2016-03-25                3            2016              12
# 1       2016-03-26                3            2016              12
# 2       2016-03-27                3            2016              12
# 3       2016-03-28                3            2016              13
# 4       2016-03-29                3            2016              13
# ..             ...              ...             ...             ...
# 452     2016-04-08                4            2016              14
# 453     2016-04-09                4            2016              14
# 454     2016-04-10                4            2016              14
# 455     2016-04-11                4            2016              15
# 456     2016-04-12                4            2016              15
#
#     converted_weekName
# 0               Friday
# 1             Saturday
# 2               Sunday
# 3               Monday
# 4              Tuesday
# ..                 ...
# 452             Friday
# 453           Saturday
# 454             Sunday
# 455             Monday
# 456            Tuesday
#
# [457 rows x 20 columns]

# %%
#3
df_2['ActivityDate']= pd.to_datetime(df_2['ActivityDate'])

# %%
df_2.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# converted_date              datetime64[ns]
# converted_month                      int64
# converted_year                       int64
# converted_week                       int64
# converted_weekName                  object
# dtype: object

# %%
df_2['converted_month']=df_2['converted_date'].dt.month

# %%
df_2
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#     converted_date  converted_month  converted_year  converted_week  \
# 0       2016-03-25                3            2016              12
# 1       2016-03-26                3            2016              12
# 2       2016-03-27                3            2016              12
# 3       2016-03-28                3            2016              13
# 4       2016-03-29                3            2016              13
# ..             ...              ...             ...             ...
# 452     2016-04-08                4            2016              14
# 453     2016-04-09                4            2016              14
# 454     2016-04-10                4            2016              14
# 455     2016-04-11                4            2016              15
# 456     2016-04-12                4            2016              15
#
#     converted_weekName
# 0               Friday
# 1             Saturday
# 2               Sunday
# 3               Monday
# 4              Tuesday
# ..                 ...
# 452             Friday
# 453           Saturday
# 454             Sunday
# 455             Monday
# 456            Tuesday
#
# [457 rows x 20 columns]

# %%
df_2['converted_year']=df_2['converted_date'].dt.year

# %%
df_2['converted_week']=df_2['converted_date'].dt.week
# Out:
# C:\Users\udeva\AppData\Local\Temp\ipykernel_19600\3297215133.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df_2['converted_week']=df_2['converted_date'].dt.week

# %%
df_2['converted_weekName']=df_2['converted_date'].dt.day_name()

# %%
df_2
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#     converted_date  converted_month  converted_year  converted_week  \
# 0       2016-03-25                3            2016              12
# 1       2016-03-26                3            2016              12
# 2       2016-03-27                3            2016              12
# 3       2016-03-28                3            2016              13
# 4       2016-03-29                3            2016              13
# ..             ...              ...             ...             ...
# 452     2016-04-08                4            2016              14
# 453     2016-04-09                4            2016              14
# 454     2016-04-10                4            2016              14
# 455     2016-04-11                4            2016              15
# 456     2016-04-12                4            2016              15
#
#     converted_weekName
# 0               Friday
# 1             Saturday
# 2               Sunday
# 3               Monday
# 4              Tuesday
# ..                 ...
# 452             Friday
# 453           Saturday
# 454             Sunday
# 455             Monday
# 456            Tuesday
#
# [457 rows x 20 columns]

# %%
#4
df_2['Id'].unique
# Out:
# <bound method Series.unique of 0      1503960366
# 1      1503960366
# 2      1503960366
# 3      1503960366
# 4      1503960366
#           ...
# 452    8877689391
# 453    8877689391
# 454    8877689391
# 455    8877689391
# 456    8877689391
# Name: Id, Length: 457, dtype: int64>

# %%
df_2['Id'].unique()
len(df_2['Id'].unique())
# Out:
# 35

# %%
df_2.groupby(['Id',"VeryActiveDistance"]).max()
# Out:
#                               ActivityDate  TotalSteps  TotalDistance  \
# Id         VeryActiveDistance
# 1503960366 0.00                 2016-04-12         224       0.140000
#            0.91                 2016-04-03       10016       6.370000
#            1.20                 2016-04-07       10198       6.440000
#            2.04                 2016-04-11       11974       7.670000
#            2.16                 2016-03-29       12041       7.850000
# ...                                    ...         ...            ...
# 8877689391 11.10                2016-04-08       23014      20.389999
#            11.73                2016-04-04       20779      18.410000
#            12.22                2016-04-06       24136      20.910000
#            14.72                2016-04-02       27572      23.389999
#            21.92                2016-04-10       28497      27.530001
#
#                                TrackerDistance  LoggedActivitiesDistance  \
# Id         VeryActiveDistance
# 1503960366 0.00                       0.140000                       0.0
#            0.91                       6.370000                       0.0
#            1.20                       6.440000                       0.0
#            2.04                       7.670000                       0.0
#            2.16                       7.850000                       0.0
# ...                                        ...                       ...
# 8877689391 11.10                     20.389999                       0.0
#            11.73                     18.410000                       0.0
#            12.22                     20.910000                       0.0
#            14.72                     23.389999                       0.0
#            21.92                     27.530001                       0.0
#
#                                ModeratelyActiveDistance  LightActiveDistance  \
# Id         VeryActiveDistance
# 1503960366 0.00                                    0.00                 0.13
#            0.91                                    1.28                 4.18
#            1.20                                    0.79                 4.45
#            2.04                                    0.57                 5.15
#            2.16                                    1.09                 4.61
# ...                                                 ...                  ...
# 8877689391 11.10                                   0.63                 8.62
#            11.73                                   0.65                 6.00
#            12.22                                   0.54                 8.08
#            14.72                                   1.21                 7.34
#            21.92                                   1.12                 4.46
#
#                                SedentaryActiveDistance  VeryActiveMinutes  \
# Id         VeryActiveDistance
# 1503960366 0.00                                   0.00                  0
#            0.91                                   0.00                 15
#            1.20                                   0.00                 17
#            2.04                                   0.00                 27
#            2.16                                   0.00                 28
# ...                                                ...                ...
# 8877689391 11.10                                  0.00                 70
#            11.73                                  0.00                 78
#            12.22                                  0.00                 87
#            14.72                                  0.01                116
#            21.92                                  0.00                128
#
#                                FairlyActiveMinutes  LightlyActiveMinutes  \
# Id         VeryActiveDistance
# 1503960366 0.00                                  0                     9
#            0.91                                 30                   314
#            1.20                                 20                   195
#            2.04                                 14                   228
#            2.16                                 28                   243
# ...                                            ...                   ...
# 8877689391 11.10                                29                   359
#            11.73                                16                   208
#            12.22                                16                   318
#            14.72                                24                   260
#            21.92                                46                   211
#
#                                SedentaryMinutes  Calories converted_date  \
# Id         VeryActiveDistance
# 1503960366 0.00                              32        50     2016-04-12
#            0.91                             655      1850     2016-04-03
#            1.20                            1208      1755     2016-04-07
#            2.04                            1173      1861     2016-04-11
#            2.16                             763      1886     2016-03-29
# ...                                         ...       ...            ...
# 8877689391 11.10                            982      4196     2016-04-08
#            11.73                           1138      3662     2016-04-04
#            12.22                           1019      4039     2016-04-06
#            14.72                           1040      4220     2016-04-02
#            21.92                           1055      4526     2016-04-10
#
#                                converted_month  converted_year  \
# Id         VeryActiveDistance
# 1503960366 0.00                              4            2016
#            0.91                              4            2016
#            1.20                              4            2016
#            2.04                              4            2016
#            2.16                              3            2016
# ...                                        ...             ...
# 8877689391 11.10                             4            2016
#            11.73                             4            2016
#            12.22                             4            2016
#            14.72                             4            2016
#            21.92                             4            2016
#
#                                converted_week converted_weekName  \
# Id         VeryActiveDistance
# 1503960366 0.00                            15            Tuesday
#            0.91                            13             Sunday
#            1.20                            14           Thursday
#            2.04                            15          Wednesday
#            2.16                            13            Tuesday
# ...                                       ...                ...
# 8877689391 11.10                           14             Friday
#            11.73                           14             Monday
#            12.22                           14          Wednesday
#            14.72                           13           Saturday
#            21.92                           14             Sunday
#
#                                TotalActiveMinutes
# Id         VeryActiveDistance
# 1503960366 0.00                                 9
#            0.91                               359
#            1.20                               232
#            2.04                               267
#            2.16                               299
# ...                                           ...
# 8877689391 11.10                              458
#            11.73                              302
#            12.22                              421
#            14.72                              400
#            21.92                              385
#
# [235 rows x 19 columns]

# %%
#5. which id is one of the active id that you have in whole dataset 
df_2["TotalActiveMinutes"]=(df_2['VeryActiveMinutes']+df_2['FairlyActiveMinutes'] + df_2['LightlyActiveMinutes'])

# %%
df_2.sort_values('TotalActiveMinutes', ascending=False).iloc[[0]]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 139  2891001357   2016-04-02        4126           3.22              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 139                  3.218688                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  ...  FairlyActiveMinutes  \
# 139                 3.22                      0.0  ...                    0
#
#      LightlyActiveMinutes  SedentaryMinutes  Calories  converted_date  \
# 139                   720               720      2881      2016-04-02
#
#     converted_month  converted_year  converted_week  converted_weekName  \
# 139               4            2016              13            Saturday
#
#     TotalActiveMinutes
# 139                720
#
# [1 rows x 21 columns]

# %%
df_2.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories',
#        'converted_date', 'converted_month', 'converted_year', 'converted_week',
#        'converted_weekName', 'TotalActiveMinutes'],
#       dtype='object')

# %%
#6. how many of them have not logged there activity find out in terms of number of ids 
len(df_2[df_2['TotalActiveMinutes']== 0]) #There are total 68 id's that have not logged their activity
# Out:
# 68

# %%
df_2[df_2['TotalActiveMinutes']== 0]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 51   1844505072   2016-04-04           0            0.0              0.0
# 52   1844505072   2016-04-05           0            0.0              0.0
# 59   1844505072   2016-04-12           0            0.0              0.0
# 96   2320127002   2016-04-01           0            0.0              0.0
# 97   2320127002   2016-04-02           0            0.0              0.0
# ..          ...          ...         ...            ...              ...
# 402  8253242879   2016-04-02           0            0.0              0.0
# 403  8253242879   2016-04-03           0            0.0              0.0
# 404  8253242879   2016-04-04           0            0.0              0.0
# 405  8253242879   2016-04-05           0            0.0              0.0
# 412  8253242879   2016-04-12           0            0.0              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 51                        0.0                 0.0                       0.0
# 52                        0.0                 0.0                       0.0
# 59                        0.0                 0.0                       0.0
# 96                        0.0                 0.0                       0.0
# 97                        0.0                 0.0                       0.0
# ..                        ...                 ...                       ...
# 402                       0.0                 0.0                       0.0
# 403                       0.0                 0.0                       0.0
# 404                       0.0                 0.0                       0.0
# 405                       0.0                 0.0                       0.0
# 412                       0.0                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  ...  FairlyActiveMinutes  \
# 51                   0.0                      0.0  ...                    0
# 52                   0.0                      0.0  ...                    0
# 59                   0.0                      0.0  ...                    0
# 96                   0.0                      0.0  ...                    0
# 97                   0.0                      0.0  ...                    0
# ..                   ...                      ...  ...                  ...
# 402                  0.0                      0.0  ...                    0
# 403                  0.0                      0.0  ...                    0
# 404                  0.0                      0.0  ...                    0
# 405                  0.0                      0.0  ...                    0
# 412                  0.0                      0.0  ...                    0
#
#      LightlyActiveMinutes  SedentaryMinutes  Calories  converted_date  \
# 51                      0               669      1347      2016-04-04
# 52                      0              1440      1347      2016-04-05
# 59                      0               426       399      2016-04-12
# 96                      0              1440      1324      2016-04-01
# 97                      0              1440      1324      2016-04-02
# ..                    ...               ...       ...             ...
# 402                     0              1440      1429      2016-04-02
# 403                     0              1440      1429      2016-04-03
# 404                     0              1440      1429      2016-04-04
# 405                     0              1440      1429      2016-04-05
# 412                     0              1440         0      2016-04-12
#
#     converted_month  converted_year  converted_week  converted_weekName  \
# 51                4            2016              14              Monday
# 52                4            2016              14             Tuesday
# 59                4            2016              15             Tuesday
# 96                4            2016              13              Friday
# 97                4            2016              13            Saturday
# ..              ...             ...             ...                 ...
# 402               4            2016              13            Saturday
# 403               4            2016              13              Sunday
# 404               4            2016              14              Monday
# 405               4            2016              14             Tuesday
# 412               4            2016              15             Tuesday
#
#     TotalActiveMinutes
# 51                   0
# 52                   0
# 59                   0
# 96                   0
# 97                   0
# ..                 ...
# 402                  0
# 403                  0
# 404                  0
# 405                  0
# 412                  0
#
# [68 rows x 21 columns]

# %%
#7. Find out who is the laziest person id that we have in dataset 
df_2[df_2['Calories']>0].sort_values(['Calories']).reset_index().iloc[[0]] #Person with ID 1503960366 is the laziest person
# Out:
#    index          Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0     18  1503960366   2016-04-12         224           0.14             0.14
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                 0.0                       0.0
#
#    LightActiveDistance  ...  FairlyActiveMinutes  LightlyActiveMinutes  \
# 0                 0.13  ...                    0                     9
#
#    SedentaryMinutes  Calories  converted_date  converted_month converted_year  \
# 0                32        50      2016-04-12                4           2016
#
#    converted_week  converted_weekName  TotalActiveMinutes
# 0              15             Tuesday                   9
#
# [1 rows x 22 columns]

# %%
#8. Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset 
#According to Internet: As a general guideline, women typically burn about 2,000 calories per day and men burn about 2,500 calories per day. These numbers are often used to determine 
#an approximate food intake for weight maintenance. As we don.t know the exact gender of the person, we will take average of both.
#i.e. 2250 calories are required to be burned per day for a healthy person.
len(df_2[df_2['Calories']>2250]['Id'].unique()) #So there are 24 persons who are healthy
# Out:
# 24

# %%
df_2[df_2['Calories']>2250]['Id'].unique()
# Out:
# array([1644430081, 1927972279, 2022484408, 2347167796, 2873212765,
#        2891001357, 4020332650, 4057192912, 4319703577, 4445114986,
#        4702921684, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8378563200, 8583815059, 8792009665, 8877689391], dtype=int64)

# %%
#And if we consider the minimum calories of the required calories burnt, then :
len(df_2[df_2['Calories']>2000]['Id'].unique())
# Out:
# 30

# %%
df_2[df_2['Calories']>2000]['Id'].unique()
# Out:
# array([1503960366, 1644430081, 1927972279, 2022484408, 2320127002,
#        2347167796, 2873212765, 2891001357, 3372868164, 4020332650,
#        4057192912, 4319703577, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
#9. how many person are not a regular person with respect to activity try to find out those 
df_2
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  ...  FairlyActiveMinutes  \
# 0                   4.07                     0.00  ...                   12
# 1                   3.91                     0.00  ...                   17
# 2                   3.71                     0.00  ...                    5
# 3                   4.95                     0.00  ...                   20
# 4                   4.61                     0.00  ...                   28
# ..                   ...                      ...  ...                  ...
# 452                 8.62                     0.00  ...                   29
# 453                 8.02                     0.00  ...                    9
# 454                 4.46                     0.00  ...                   46
# 455                 6.37                     0.01  ...                    7
# 456                 1.78                     0.00  ...                    0
#
#      LightlyActiveMinutes  SedentaryMinutes  Calories  converted_date  \
# 0                     205               804      1819      2016-03-25
# 1                     274               588      2154      2016-03-26
# 2                     268               605      1944      2016-03-27
# 3                     224              1080      1932      2016-03-28
# 4                     243               763      1886      2016-03-29
# ..                    ...               ...       ...             ...
# 452                   359               982      4196      2016-04-08
# 453                   289              1052      3841      2016-04-09
# 454                   211              1055      4526      2016-04-10
# 455                   225              1190      2820      2016-04-11
# 456                    58               531       938      2016-04-12
#
#     converted_month  converted_year  converted_week  converted_weekName  \
# 0                 3            2016              12              Friday
# 1                 3            2016              12            Saturday
# 2                 3            2016              12              Sunday
# 3                 3            2016              13              Monday
# 4                 3            2016              13             Tuesday
# ..              ...             ...             ...                 ...
# 452               4            2016              14              Friday
# 453               4            2016              14            Saturday
# 454               4            2016              14              Sunday
# 455               4            2016              15              Monday
# 456               4            2016              15             Tuesday
#
#     TotalActiveMinutes
# 0                  250
# 1                  380
# 2                  329
# 3                  283
# 4                  299
# ..                 ...
# 452                458
# 453                388
# 454                385
# 455                250
# 456                 58
#
# [457 rows x 21 columns]

# %%
#10. who is the third most active person in this dataset find out those in pandas and in sql both . 
df_2.sort_values("TotalActiveMinutes", ascending = False).reset_index().iloc[[2]]
# Out:
#    index          Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 2    142  2891001357   2016-04-05        2063           1.61              0.0
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 2                  1.609344                 0.0                       0.0
#
#    LightActiveDistance  ...  FairlyActiveMinutes  LightlyActiveMinutes  \
# 2                 1.61  ...                    0                   630
#
#    SedentaryMinutes  Calories  converted_date  converted_month converted_year  \
# 2                99      1144      2016-04-05                4           2016
#
#    converted_week  converted_weekName  TotalActiveMinutes
# 2              14             Tuesday                 630
#
# [1 rows x 22 columns]

# %%
#11. who is the 5th most laziest person avilable in dataset find it out 
df_2.sort_values('TotalSteps').reset_index().iloc[[4]]
# Out:
#    index          Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 4    341  6391747486   2016-04-08           0            0.0              0.0
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 4                       0.0                 0.0                       0.0
#
#    LightActiveDistance  ...  FairlyActiveMinutes  LightlyActiveMinutes  \
# 4                  0.0  ...                    0                     0
#
#    SedentaryMinutes  Calories  converted_date  converted_month converted_year  \
# 4              1440      1820      2016-04-08                4           2016
#
#    converted_week  converted_weekName  TotalActiveMinutes
# 4              14              Friday                   0
#
# [1 rows x 22 columns]

# %%
#12. what is a total Cumulative Calories burn for a person find out 
df_2k = df_2.groupby('Id',as_index = False).sum()
df_2k
# Out:
#             Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0   1503960366      221170     144.540001       144.540001
# 1   1624580081       80299      52.189999        52.189999
# 2   1644430081       92748      67.490000        67.490000
# 3   1844505072       43687      28.880000        28.880000
# 4   1927972279       26170      18.130000        18.130000
# 5   2022484408      146099     105.290001       105.290001
# 6   2026352035       40713      25.240000        25.240000
# 7   2320127002       37661      25.470000        25.470000
# 8   2347167796      147001      97.670001        97.670001
# 9   2873212765       79639      53.630001        53.630001
# 10  2891001357        6189       4.830000         0.000000
# 11  3372868164       61275      42.160000        42.160000
# 12  3977333714      103967      69.679999        69.679999
# 13  4020332650      184851     132.600000       132.600000
# 14  4057192912       60391      44.450000        45.020000
# 15  4319703577       93847      63.070000        63.070000
# 16  4388161847           0       0.000000         0.000000
# 17  4445114986       64396      43.600000        43.600000
# 18  4558609924       69423      45.880000        45.880000
# 19  4702921684      119151      96.690000        96.690000
# 20  5553957443      100257      65.500000        65.500000
# 21  5577150313       94690      70.930000        70.930000
# 22  6117666160       82486      62.270000        62.270000
# 23  6290855005       16181      12.230000        12.230000
# 24  6391747486       12032       9.670000         0.910000
# 25  6775888955       50031      35.870000        35.870000
# 26  6962181067      176956     121.070000       117.400001
# 27  7007744171      147124     106.280000        98.440000
# 28  7086361926       73247      49.130000        49.130000
# 29  8053475328      163288     127.340000       127.340000
# 30  8253242879       28679      20.150000        20.150000
# 31  8378563200       97623      77.420000        77.420000
# 32  8583815059       24364      19.020000        19.020000
# 33  8792009665       37139      23.770000        23.770000
# 34  8877689391      209005     169.089998       169.089998
#
#     LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                   0.000000           52.890000                     12.07
# 1                   0.000000            0.980000                      0.52
# 2                   0.000000           11.340000                     20.30
# 3                   0.000000            0.610000                      0.37
# 4                   0.000000            0.000000                      0.74
# 5                   0.000000           37.030000                     10.61
# 6                   0.000000            0.000000                      0.00
# 7                   0.000000            0.950000                      0.54
# 8                   0.000000           12.920000                     18.91
# 9                   0.000000            3.960000                      3.13
# 10                  9.656064            0.000000                      0.00
# 11                  0.000000            7.440000                      1.14
# 12                  0.000000           10.020000                     16.43
# 13                  0.000000            5.300000                      6.29
# 14                  0.055843            3.200000                      7.78
# 15                  0.000000            5.540000                      8.60
# 16                  0.000000            0.000000                      0.00
# 17                  0.000000            6.350000                      0.62
# 18                  0.000000            2.170000                      1.37
# 19                  0.000000            3.570000                     12.17
# 20                  0.000000           18.140000                     10.43
# 21                  0.000000           34.260000                      7.12
# 22                  0.000000            0.420000                      2.73
# 23                  0.000000            2.020000                      3.68
# 24                  8.754830            2.030000                      0.05
# 25                  0.000000            8.480000                     10.59
# 26                 14.052416           36.130000                     24.99
# 27                 34.351326           42.479999                      7.86
# 28                  0.000000           18.350000                      6.66
# 29                  0.000000           93.930000                      5.43
# 30                  0.000000            7.240000                      3.39
# 31                 15.127832           23.580000                      6.32
# 32                  0.000000            0.370000                      0.73
# 33                  0.000000            0.580000                      1.37
# 34                  0.000000           87.390000                      5.80
#
#     LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0             79.390000                     0.00                681
# 1             50.530000                     0.10                 14
# 2             35.800000                     0.08                148
# 3             27.890000                     0.00                  9
# 4             17.390000                     0.00                  0
# 5             57.670000                     0.00                481
# 6             25.240000                     0.00                  0
# 7             23.979999                     0.00                 11
# 8             65.809999                     0.00                177
# 9             46.520000                     0.02                 61
# 10             4.830000                     0.00                  0
# 11            33.460000                     0.14                118
# 12            43.070000                     0.00                146
# 13            71.710000                     0.20                130
# 14            33.170000                     0.06                 40
# 15            48.910000                     0.00                 79
# 16             0.000000                     0.00                  0
# 17            36.609999                     0.00                 76
# 18            42.320000                     0.00                 52
# 19            80.840000                     0.00                 44
# 20            36.910000                     0.00                283
# 21            29.520000                     0.00                900
# 22            59.090000                     0.00                  5
# 23             6.530000                     0.00                 78
# 24             7.590000                     0.00                 46
# 25            16.410000                     0.00                179
# 26            59.850000                     0.10                495
# 27            55.890000                     0.05                536
# 28            23.920000                     0.06                315
# 29            27.950000                     0.00                933
# 30             9.510000                     0.03                 70
# 31            47.540000                     0.00                665
# 32            17.880000                     0.00                  5
# 33            21.820000                     0.00                 18
# 34            75.270001                     0.03                802
#
#     FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   301                  4336             15387     34128
# 1                    11                  2300             24288     25705
# 2                   435                  2277             10342     29164
# 3                     9                  1902             12424     19391
# 4                    20                  1340             11435     27048
# 5                   270                  3046             12707     29704
# 6                     0                  2032              7910     16266
# 7                    13                  1511             14991     18385
# 8                   347                  3803             10258     30320
# 9                    72                  3303             13643     20349
# 10                  660                  1350              8799     18187
# 11                   35                  2869             10851     18603
# 12                  375                  2483              8505     16777
# 13                  245                  4172             34663     98412
# 14                  169                  1384             43458     60913
# 15                  219                  2984              9361     23931
# 16                    0                     0             11074     14442
# 17                   14                  3009             12921     31617
# 18                   33                  2998             13024     21962
# 19                  259                  3701             10901     42322
# 20                  200                  2200              7293     21630
# 21                  310                  1730              7324     36303
# 22                   41                  2999              8641     20993
# 23                  107                   393             12896     21656
# 24                    6                   309             11357     15868
# 25                  443                  1116              9161     24523
# 26                  406                  3620              8488     29249
# 27                  195                  3330             12008     31525
# 28                  212                  1215             10666     26124
# 29                  125                  1698             12259     31825
# 30                   56                   711             16228     17556
# 31                  124                  2027              8210     40274
# 32                   15                  1097             10094     19130
# 33                   65                  1585             10723     24884
# 34                  181                  2892             12554     41414
#
#     converted_month  converted_year  converted_week  TotalActiveMinutes
# 0                69           38304             255                5318
# 1                69           38304             255                2325
# 2                40           20160             137                2860
# 3                48           24192             167                1920
# 4                48           24192             167                1360
# 5                48           24192             167                3797
# 6                48           24192             167                2032
# 7                48           24192             167                1535
# 8                57           30240             206                4327
# 9                48           24192             167                3436
# 10               29           16128             106                2010
# 11               40           20160             137                3022
# 12               48           24192             167                3004
# 13              108           64512             400                4547
# 14              108           64512             400                1593
# 15               45           24192             162                3282
# 16               29           16128             106                   0
# 17               57           30240             206                3099
# 18               48           24192             167                3083
# 19               57           30240             206                4004
# 20               48           24192             167                2683
# 21               44           22176             152                2940
# 22               40           20160             137                3045
# 23               40           20160             137                 578
# 24               36           18144             123                 361
# 25               36           18144             123                1738
# 26               54           28224             193                4521
# 27               48           24192             167                4061
# 28               48           24192             167                1742
# 29               44           22176             154                2756
# 30               48           24192             167                 837
# 31               48           24192             167                2816
# 32               32           16128             109                1117
# 33               48           24192             167                1668
# 34               48           24192             167                3875

# %%
df_2[[ "Id", 'Calories']]
# Out:
#              Id  Calories
# 0    1503960366      1819
# 1    1503960366      2154
# 2    1503960366      1944
# 3    1503960366      1932
# 4    1503960366      1886
# ..          ...       ...
# 452  8877689391      4196
# 453  8877689391      3841
# 454  8877689391      4526
# 455  8877689391      2820
# 456  8877689391       938
#
# [457 rows x 2 columns]

# %%
#Task 2 - Superstore_USA
1 . Load this data in sql and in pandas with a relation in sql 
2 . While loading this data you dont have to create a table manually. You can use any automated approach to create a table and load a data in bulk in table 
3 . Find out how return that we ahve recived and with a product id 
4 . try  to join order and return data both in sql and pandas 
5 . Try to find out how many unique customer that we have 
6 . try to find out in how many regions we are selling a product and who is a manager for a respective region 
7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
9 . base on question number 8 find out for which order id we have shipment duration more than 10 days 
10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
11 . Gorup by region and find out which region is more profitable 
12 . Try to find out overalll in which country we are giving more didscount 
13 . Give me a list of unique postal code 
14 . which customer segement is more profitalble find it out . 
15 . try to find out the 10th most loss making product catagory . 
16 . Try to find out 10 top  product with highest margins

# %%
# load the data set into mysql work bench automatic insertion entire csv file
# !pip install mysqlclient
import pandas as pd 
mysql_engine = ("mysql://kishor:mysql123@localhost:3306/ineuron") # It will help to connect mysql server as well as database
data=pd.read_csv(r"D:\New folder(2)\Superstore_USA.csv") # It will help to read the csv file
data.to_sql('superstore_usa1',mysql_engine) # It help to load the data in mysql workbench

# %%
import mysql.connector as connection
mydb = connection.connect(host='localhost',user='kishor',password='mysql123',use_pure=True)
con = mydb.cursor()
con.execute('show databases')
con.fetchall()
# Out:
# [('imp',),
#  ('ineuron',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('uday',)]

# %%
con.execute("use ineuron")

# %%
con.execute("select * from superstore_usa1")

# %%
#for i in con.fetchall():  # we are trying to read the mysql workbench table into jupyter notebook one by one
    #print(i)

# %%
#To bulk load data in MySQL database, we need to use mannual process which is given below:

#First to load excel file directly into database, we have to convert it into CSV file format. Then followthe steps.
#step 1 : Right click on table 
#step 2 : Select "Table Data Import Wizard"
#step 3 : Select the file which we have to load (in our case, it is SuperStore_USA.csv) and press next.
#step 4 : Select create new table and give the table name and press next.
#step 5 : Select the required conditions and press next. The data is loaded Successfully

# %%
import pandas as pd
orders=pd.read_excel(r"D:\New folder(2)\Superstore_USA.xlsx")

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
orders
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#        Region State or Province        City  Postal Code Order Date  \
# 0     Central          Illinois     Addison        60101 2012-05-28
# 1        West        Washington   Anacortes        98221 2010-07-07
# 2        West        Washington   Anacortes        98221 2011-07-27
# 3        West        Washington   Anacortes        98221 2011-07-27
# 4        West        Washington   Anacortes        98221 2011-07-27
# ...       ...               ...         ...          ...        ...
# 9421     East     West Virginia  Charleston        25314 2013-05-14
# 9422     East     West Virginia  Charleston        25314 2013-05-14
# 9423     East     West Virginia  Charleston        25314 2013-09-12
# 9424     West           Wyoming    Cheyenne        82001 2010-02-08
# 9425     West           Wyoming    Cheyenne        82001 2013-09-12
#
#       Ship Date       Profit  Quantity ordered new    Sales Order ID
# 0    2012-05-30     1.320000                     2     5.90    88525
# 1    2010-07-08     4.560000                     4    13.01    88522
# 2    2011-07-28   -47.640000                     7    49.92    88523
# 3    2011-07-28   -30.510000                     7    41.64    88523
# 4    2011-07-27   998.202300                     8  1446.67    88523
# ...         ...          ...                   ...      ...      ...
# 9421 2013-05-15   137.860000                    13   447.87    87532
# 9422 2013-05-14   -39.070000                     3    13.23    87532
# 9423 2013-09-14 -1225.029097                     4  2215.93    87533
# 9424 2010-02-11   349.485000                     5   506.50    87530
# 9425 2013-09-14    78.062400                    23   172.48    87533
#
# [9426 rows x 24 columns]

# %%
#3. Find out how much returns we have recieved and with a product id 
import pandas as pd
xls = pd.ExcelFile(r"D:\New folder(2)\Superstore_USA.xlsx")
returns = pd.read_excel(xls, 'Returns',names = ["OrderID","Status"])
users = pd.read_excel(xls, 'Users')

# %%
returns
# Out:
#       OrderID    Status
# 0          65  Returned
# 1         612  Returned
# 2         614  Returned
# 3         678  Returned
# 4         710  Returned
# ...       ...       ...
# 1629   182681  Returned
# 1630   182683  Returned
# 1631   182750  Returned
# 1632   182781  Returned
# 1633   182906  Returned
#
# [1634 rows x 2 columns]

# %%
orders
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#        Region State or Province        City  Postal Code Order Date  \
# 0     Central          Illinois     Addison        60101 2012-05-28
# 1        West        Washington   Anacortes        98221 2010-07-07
# 2        West        Washington   Anacortes        98221 2011-07-27
# 3        West        Washington   Anacortes        98221 2011-07-27
# 4        West        Washington   Anacortes        98221 2011-07-27
# ...       ...               ...         ...          ...        ...
# 9421     East     West Virginia  Charleston        25314 2013-05-14
# 9422     East     West Virginia  Charleston        25314 2013-05-14
# 9423     East     West Virginia  Charleston        25314 2013-09-12
# 9424     West           Wyoming    Cheyenne        82001 2010-02-08
# 9425     West           Wyoming    Cheyenne        82001 2013-09-12
#
#       Ship Date       Profit  Quantity ordered new    Sales Order ID
# 0    2012-05-30     1.320000                     2     5.90    88525
# 1    2010-07-08     4.560000                     4    13.01    88522
# 2    2011-07-28   -47.640000                     7    49.92    88523
# 3    2011-07-28   -30.510000                     7    41.64    88523
# 4    2011-07-27   998.202300                     8  1446.67    88523
# ...         ...          ...                   ...      ...      ...
# 9421 2013-05-15   137.860000                    13   447.87    87532
# 9422 2013-05-14   -39.070000                     3    13.23    87532
# 9423 2013-09-14 -1225.029097                     4  2215.93    87533
# 9424 2010-02-11   349.485000                     5   506.50    87530
# 9425 2013-09-14    78.062400                    23   172.48    87533
#
# [9426 rows x 24 columns]

# %%
import pandas as pd

# %%
order_returns=pd.concat(pd.read_excel(r"D:\New folder(2)\Superstore_USA.xlsx",sheet_name=None),ignore_index=True)

# %%
a=pd.DataFrame(order_returns)

# %%
order_returns.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Status', 'Manager'],
#       dtype='object')

# %%
a[(a['Status']=='Returned')]['Order ID'] #There are total 98 orders which were returned
#In the question, Product ID is mentioned which is not available, So I have given the order ID instead.
# Out:
# 9426         65.0
# 9427        612.0
# 9428        614.0
# 9429        678.0
# 9430        710.0
#            ...
# 11055    182681.0
# 11056    182683.0
# 11057    182750.0
# 11058    182781.0
# 11059    182906.0
# Name: Order ID, Length: 1634, dtype: float64

# %%
#4. try  to join order and return data both in sql and pandas 
pd.merge(orders, returns)

#Join in sql
#select * from returns_done INNER JOIN orders ON orders.OrderID=returns_done.orderID;

# %%
#5. Try to find out how many unique customer that we have
cursor = mydb.cursor()
cursor.execute("select count(distinct `Customer ID`) from superstore_usa1") #2703
print(cursor.fetchall())
cursor.close()
# Out:
# [(2703,)]
# True

# %%
total = orders['Customer ID'].unique()

# %%
len(total)
# Out:
# 2703

# %%
#6. try to find out in how many regions we are selling a product and who is a manager for a respective region 
users
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
len(orders['Region'].unique()) #There are 4 regions in total and the respective managers for each region are listed in above table 'users'
# Out:
# 4

# %%
#7. find out how many different different shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
Shipment_mode = orders['Ship Mode']

# %%
count = pd.Series(Shipment_mode).value_counts()
count
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
s = pd.DataFrame(count)

# %%
total_ship_mode = s.sum()

# %%
((s[['Ship Mode']])/total_ship_mode)*100 #percentage usablity of all the shipment mode with respect to dataset
# Out:
#                 Ship Mode
# Regular Air     74.644600
# Delivery Truck  13.611288
# Express Air     11.744112

# %%
#8. Create a new coulmn and try to find our a diffrence between order date and shipment date
orders["difference_date"] =  orders['Ship Date'] - orders['Order Date']

# %%
orders
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#      State or Province        City Postal Code  Order Date  Ship Date  \
# 0             Illinois     Addison       60101  2012-05-28 2012-05-30
# 1           Washington   Anacortes       98221  2010-07-07 2010-07-08
# 2           Washington   Anacortes       98221  2011-07-27 2011-07-28
# 3           Washington   Anacortes       98221  2011-07-27 2011-07-28
# 4           Washington   Anacortes       98221  2011-07-27 2011-07-27
# ...                ...         ...         ...         ...        ...
# 9421     West Virginia  Charleston       25314  2013-05-14 2013-05-15
# 9422     West Virginia  Charleston       25314  2013-05-14 2013-05-14
# 9423     West Virginia  Charleston       25314  2013-09-12 2013-09-14
# 9424           Wyoming    Cheyenne       82001  2010-02-08 2010-02-11
# 9425           Wyoming    Cheyenne       82001  2013-09-12 2013-09-14
#
#            Profit Quantity ordered new    Sales Order ID difference_date
# 0        1.320000                    2     5.90    88525          2 days
# 1        4.560000                    4    13.01    88522          1 days
# 2      -47.640000                    7    49.92    88523          1 days
# 3      -30.510000                    7    41.64    88523          1 days
# 4      998.202300                    8  1446.67    88523          0 days
# ...           ...                  ...      ...      ...             ...
# 9421   137.860000                   13   447.87    87532          1 days
# 9422   -39.070000                    3    13.23    87532          0 days
# 9423 -1225.029097                    4  2215.93    87533          2 days
# 9424   349.485000                    5   506.50    87530          3 days
# 9425    78.062400                   23   172.48    87533          2 days
#
# [9426 rows x 25 columns]

# %%
#9. Based on Question number 8, find out for which order id we have shipment duration more than 10 days 
difference = orders['difference_date']

# %%
orders[(orders['difference_date'].dt.components['days']>10)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# 5673   19005            Low      0.06       65.99           2.50         2088
# 5859   24392            Low      0.05       29.89           1.99         2143
# 5881   21257            Low      0.05        7.99           5.03         2153
# 8607   26351         Medium      0.00        8.32           2.38         3119
# 8609   26350         Medium      0.07      180.98          55.24         3119
# 8610   26352         Medium      0.06        4.20           2.26         3119
# 8973   20750            Low      0.06      125.99           8.08         3248
# 8982    2748            Low      0.03       11.97           5.81         3251
# 8983    2749            Low      0.08      195.99           4.20         3251
# 8993    2750            Low      0.06      125.99           8.08         3251
# 8996   20748            Low      0.03       11.97           5.81         3252
# 8997   20749            Low      0.08      195.99           4.20         3252
#
#                 Customer Name       Ship Mode Customer Segment  \
# 643   Brenda Nelson Blanchard     Regular Air        Corporate
# 1548               Dana Desai     Regular Air   Small Business
# 1549               Dana Desai     Express Air   Small Business
# 1678       Christopher Bryant  Delivery Truck         Consumer
# 1679       Christopher Bryant     Regular Air         Consumer
# 1680       Christopher Bryant     Regular Air         Consumer
# 1697               Neal Wolfe  Delivery Truck         Consumer
# 1698               Neal Wolfe     Regular Air         Consumer
# 1699               Neal Wolfe     Regular Air         Consumer
# 2515          Virginia Rivera     Regular Air      Home Office
# 5548          Ricky Dougherty     Regular Air         Consumer
# 5673             Carrie Boyle     Regular Air        Corporate
# 5859            Lester Sawyer     Regular Air      Home Office
# 5881               Anna Glenn     Regular Air      Home Office
# 8607              Jay Hubbard     Express Air        Corporate
# 8609              Jay Hubbard  Delivery Truck        Corporate
# 8610              Jay Hubbard     Regular Air        Corporate
# 8973            Earl Donnelly     Express Air        Corporate
# 8982             Peter Brooks     Regular Air        Corporate
# 8983             Peter Brooks     Regular Air        Corporate
# 8993             Peter Brooks     Express Air        Corporate
# 8996           Milton Harrell     Regular Air        Corporate
# 8997           Milton Harrell     Regular Air        Corporate
#
#      Product Category  ... State or Province           City Postal Code  \
# 643   Office Supplies  ...         Minnesota      Richfield       55423
# 1548       Technology  ...           Indiana    Bloomington       47401
# 1549  Office Supplies  ...           Indiana    Bloomington       47401
# 1678        Furniture  ...        California    Santa Clara       95051
# 1679  Office Supplies  ...        California    Santa Clara       95051
# 1680       Technology  ...        California    Santa Clara       95051
# 1697        Furniture  ...        Washington        Seattle       98119
# 1698  Office Supplies  ...        Washington        Seattle       98119
# 1699       Technology  ...        Washington        Seattle       98119
# 2515  Office Supplies  ...        California   Redwood City       94061
# 5548  Office Supplies  ...      South Dakota      Brookings       57006
# 5673       Technology  ...          New York   Mount Vernon       10550
# 5859       Technology  ...          Virginia        Fairfax       20151
# 5881       Technology  ...        California       Pasadena       91104
# 8607       Technology  ...           Florida        Orlando       32839
# 8609  Office Supplies  ...           Florida        Orlando       32839
# 8610  Office Supplies  ...           Florida        Orlando       32839
# 8973       Technology  ...         Louisiana        Slidell       70458
# 8982  Office Supplies  ...          New York  New York City       10112
# 8983       Technology  ...          New York  New York City       10112
# 8993       Technology  ...          New York  New York City       10112
# 8996  Office Supplies  ...          New York      Rotterdam       12306
# 8997       Technology  ...          New York      Rotterdam       12306
#
#       Order Date  Ship Date     Profit Quantity ordered new     Sales  \
# 643   2011-12-29 2012-03-22    58.5000                   19    204.67
# 1548  2011-12-30 2012-01-10   375.7050                    6    587.46
# 1549  2011-12-30 2012-01-14   -47.3950                   12     79.37
# 1678  2011-12-30 2012-01-16  -211.8850                   21   2699.94
# 1679  2011-12-30 2012-01-10   355.0119                   10    514.51
# 1680  2011-12-30 2012-01-27  1021.4001                   16   1480.29
# 1697  2011-12-30 2012-01-16  -423.7700                   83  10671.20
# 1698  2011-12-30 2012-01-10   469.6900                   41   2109.51
# 1699  2011-12-30 2012-01-27   727.3620                   65   6013.69
# 2515  2011-12-30 2012-03-31     5.8200                   10     22.35
# 5548  2011-12-30 2012-01-13    66.2250                   21    121.51
# 5673  2011-12-28 2012-01-14   187.4880                    8    451.34
# 5859  2011-12-26 2012-01-17  4230.2001                   12    344.16
# 5881  2011-12-26 2012-01-19   -23.4520                    2     15.56
# 8607  2011-12-29 2012-01-16 -1075.3960                   19    170.62
# 8609  2013-12-29 2014-01-15  -147.5180                   25   4529.95
# 8610  2013-12-29 2014-01-17  -689.8738                    2      9.64
# 8973  2011-12-26 2012-01-14     2.4780                   20   2180.31
# 8982  2011-12-26 2012-01-22   -31.7400                   31    388.52
# 8983  2011-12-26 2012-01-26  -557.9530                   13   2092.05
# 8993  2013-12-26 2014-01-14  1304.5590                   86   9375.35
# 8996  2011-12-26 2012-01-22   -15.8700                    8    100.26
# 8997  2011-12-26 2012-01-26  -278.9765                    3    482.78
#
#      Order ID difference_date
# 643     87215         84 days
# 1548    86318         11 days
# 1549    86318         15 days
# 1678    87957         17 days
# 1679    87957         11 days
# 1680    87957         28 days
# 1697    19556         17 days
# 1698    19556         11 days
# 1699    19556         28 days
# 2515    86177         92 days
# 5548    88223         14 days
# 5673    88352         17 days
# 5859    87572         22 days
# 5881    91294         24 days
# 8607    86434         18 days
# 8609    86436         17 days
# 8610    86436         19 days
# 8973    87300         19 days
# 8982    19841         27 days
# 8983    19841         31 days
# 8993    19841         19 days
# 8996    87300         27 days
# 8997    87300         31 days
#
# [23 rows x 25 columns]

# %%
orders[(orders['difference_date'].dt.components['days']>10)]['Order ID']
# Out:
# 643     87215
# 1548    86318
# 1549    86318
# 1678    87957
# 1679    87957
# 1680    87957
# 1697    19556
# 1698    19556
# 1699    19556
# 2515    86177
# 5548    88223
# 5673    88352
# 5859    87572
# 5881    91294
# 8607    86434
# 8609    86436
# 8610    86436
# 8973    87300
# 8982    19841
# 8983    19841
# 8993    19841
# 8996    87300
# 8997    87300
# Name: Order ID, dtype: int64

# %%
#10. Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
all_data = pd.concat([orders,returns])

# %%
pd.merge()

# %%
orders.join(df11, how = 'right')

# %%
all_data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date',
#        'OrderID', 'Status'],
#       dtype='object')

# %%
all_data[(all_data['difference_date'].dt.components['days']>15)]
# Out:
#        Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 643   18246.0       Critical      0.05       11.09           5.25
# 1678  20703.0  Not Specified      0.07      130.98          30.00
# 1680  20705.0  Not Specified      0.08      115.99           4.23
# 1697   2703.0  Not Specified      0.07      130.98          30.00
# 1699   2705.0  Not Specified      0.08      115.99           4.23
# 2515  18060.0            Low      0.02        2.21           1.00
# 5673  19005.0            Low      0.06       65.99           2.50
# 5859  24392.0            Low      0.05       29.89           1.99
# 5881  21257.0            Low      0.05        7.99           5.03
# 8607  26351.0         Medium      0.00        8.32           2.38
# 8609  26350.0         Medium      0.07      180.98          55.24
# 8610  26352.0         Medium      0.06        4.20           2.26
# 8973  20750.0            Low      0.06      125.99           8.08
# 8982   2748.0            Low      0.03       11.97           5.81
# 8983   2749.0            Low      0.08      195.99           4.20
# 8993   2750.0            Low      0.06      125.99           8.08
# 8996  20748.0            Low      0.03       11.97           5.81
# 8997  20749.0            Low      0.08      195.99           4.20
#
#       Customer ID            Customer Name       Ship Mode Customer Segment  \
# 643         250.0  Brenda Nelson Blanchard     Regular Air        Corporate
# 1678        637.0       Christopher Bryant  Delivery Truck         Consumer
# 1680        637.0       Christopher Bryant     Regular Air         Consumer
# 1697        640.0               Neal Wolfe  Delivery Truck         Consumer
# 1699        640.0               Neal Wolfe     Regular Air         Consumer
# 2515        964.0          Virginia Rivera     Regular Air      Home Office
# 5673       2088.0             Carrie Boyle     Regular Air        Corporate
# 5859       2143.0            Lester Sawyer     Regular Air      Home Office
# 5881       2153.0               Anna Glenn     Regular Air      Home Office
# 8607       3119.0              Jay Hubbard     Express Air        Corporate
# 8609       3119.0              Jay Hubbard  Delivery Truck        Corporate
# 8610       3119.0              Jay Hubbard     Regular Air        Corporate
# 8973       3248.0            Earl Donnelly     Express Air        Corporate
# 8982       3251.0             Peter Brooks     Regular Air        Corporate
# 8983       3251.0             Peter Brooks     Regular Air        Corporate
# 8993       3251.0             Peter Brooks     Express Air        Corporate
# 8996       3252.0           Milton Harrell     Regular Air        Corporate
# 8997       3252.0           Milton Harrell     Regular Air        Corporate
#
#      Product Category  ... Postal Code Order Date  Ship Date     Profit  \
# 643   Office Supplies  ...     55423.0 2011-12-29 2012-03-22    58.5000
# 1678        Furniture  ...     95051.0 2011-12-30 2012-01-16  -211.8850
# 1680       Technology  ...     95051.0 2011-12-30 2012-01-27  1021.4001
# 1697        Furniture  ...     98119.0 2011-12-30 2012-01-16  -423.7700
# 1699       Technology  ...     98119.0 2011-12-30 2012-01-27   727.3620
# 2515  Office Supplies  ...     94061.0 2011-12-30 2012-03-31     5.8200
# 5673       Technology  ...     10550.0 2011-12-28 2012-01-14   187.4880
# 5859       Technology  ...     20151.0 2011-12-26 2012-01-17  4230.2001
# 5881       Technology  ...     91104.0 2011-12-26 2012-01-19   -23.4520
# 8607       Technology  ...     32839.0 2011-12-29 2012-01-16 -1075.3960
# 8609  Office Supplies  ...     32839.0 2013-12-29 2014-01-15  -147.5180
# 8610  Office Supplies  ...     32839.0 2013-12-29 2014-01-17  -689.8738
# 8973       Technology  ...     70458.0 2011-12-26 2012-01-14     2.4780
# 8982  Office Supplies  ...     10112.0 2011-12-26 2012-01-22   -31.7400
# 8983       Technology  ...     10112.0 2011-12-26 2012-01-26  -557.9530
# 8993       Technology  ...     10112.0 2013-12-26 2014-01-14  1304.5590
# 8996  Office Supplies  ...     12306.0 2011-12-26 2012-01-22   -15.8700
# 8997       Technology  ...     12306.0 2011-12-26 2012-01-26  -278.9765
#
#      Quantity ordered new     Sales Order ID  difference_date OrderID Status
# 643                  19.0    204.67  87215.0          84 days     NaN    NaN
# 1678                 21.0   2699.94  87957.0          17 days     NaN    NaN
# 1680                 16.0   1480.29  87957.0          28 days     NaN    NaN
# 1697                 83.0  10671.20  19556.0          17 days     NaN    NaN
# 1699                 65.0   6013.69  19556.0          28 days     NaN    NaN
# 2515                 10.0     22.35  86177.0          92 days     NaN    NaN
# 5673                  8.0    451.34  88352.0          17 days     NaN    NaN
# 5859                 12.0    344.16  87572.0          22 days     NaN    NaN
# 5881                  2.0     15.56  91294.0          24 days     NaN    NaN
# 8607                 19.0    170.62  86434.0          18 days     NaN    NaN
# 8609                 25.0   4529.95  86436.0          17 days     NaN    NaN
# 8610                  2.0      9.64  86436.0          19 days     NaN    NaN
# 8973                 20.0   2180.31  87300.0          19 days     NaN    NaN
# 8982                 31.0    388.52  19841.0          27 days     NaN    NaN
# 8983                 13.0   2092.05  19841.0          31 days     NaN    NaN
# 8993                 86.0   9375.35  19841.0          19 days     NaN    NaN
# 8996                  8.0    100.26  87300.0          27 days     NaN    NaN
# 8997                  3.0    482.78  87300.0          31 days     NaN    NaN
#
# [18 rows x 27 columns]

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date'],
#       dtype='object')

# %%
#11. Group by region and find out which region is most profitable 
orders.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = True)
# Out:
#     Region  Profit
# 2    South    1954
# 3     West    2284
# 1     East    2289
# 0  Central    2899

# %%
orders.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = True).max() #West Region is most Profitable
# Out:
# Region    West
# Profit    2899
# dtype: object

# %%
orders['Discount'].unique()
# Out:
# array([0.01, 0.03, 0.  , 0.09, 0.08, 0.02, 0.07, 0.1 , 0.05, 0.06, 0.04,
#        0.11, 0.17, 0.16, 0.25, 0.21])

# %%
#12. Try to find out overall in which country we are giving more discount 
[orders[orders['Discount']>0.1]['Region']] #In central region, we are giving the most discounts.
# Out:
# [5990    Central
#  5991    Central
#  6000    Central
#  8649    Central
#  8661    Central
#  Name: Region, dtype: object]

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date'],
#       dtype='object')

# %%
#13. Give me a list of unique postal code 
orders['Postal Code'].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
orders[orders["Profit"]>100].nunique()
# Out:
# Row ID                  2635
# Order Priority             5
# Discount                  12
# Unit Price               522
# Shipping Cost            403
# Customer ID             1579
# Customer Name           1579
# Ship Mode                  3
# Customer Segment           4
# Product Category           3
# Product Sub-Category      17
# Product Container          7
# Product Name             775
# Product Base Margin       51
# Region                     4
# State or Province         49
# City                    1106
# Postal Code             1278
# Order Date              1084
# Ship Date               1136
# Profit                  2584
# Quantity ordered new      99
# Sales                   2619
# Order ID                2318
# difference_date           15
# dtype: int64

# %%
#14 . which customer segement is more profitable find it out . 
orders.groupby(['Customer Segment'])['Profit'].aggregate('count') #The corporate Customer segment is more profitable than others
# Out:
# Customer Segment
# Consumer          1894
# Corporate         3375
# Home Office       2316
# Small Business    1841
# Name: Profit, dtype: int64

# %%
#15. try to find out the 10th most loss making product catagory . 
orders[orders['Profit']<0].reset_index().sort_values('Profit', ascending = True).head(10)
# Out:
#       index  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 2291   4659   18306         Medium      0.08      175.99           4.99
# 2121   4338   20972            Low      0.01       24.95           2.99
# 3811   7800   23213            Low      0.09     6783.02          24.49
# 2381   4844   21284       Critical      0.04      880.98          44.55
# 2660   5402   24076         Medium      0.04     6783.02          24.49
# 2664   5409   22942           High      0.05     3502.14           8.73
# 3771   7725   21048  Not Specified      0.06     6783.02          24.49
# 1061   2191   21575  Not Specified      0.05     3499.99          24.49
# 1977   4068   21917           High      0.06     3502.14           8.73
# 2387   4857   24251           High      0.05     3502.14           8.73
#
#       Customer ID         Customer Name       Ship Mode Customer Segment  ...  \
# 2291         1738          Dean Solomon     Regular Air        Corporate  ...
# 2121         1632            Lori Wolfe     Regular Air      Home Office  ...
# 3811         2855          Vicki Womble     Regular Air         Consumer  ...
# 2381         1793        Derek Jernigan  Delivery Truck      Home Office  ...
# 2660         2004  James Dickinson Ball     Regular Air      Home Office  ...
# 2664         2006          Cynthia Khan  Delivery Truck      Home Office  ...
# 3771         2825          Carole Rosen     Regular Air         Consumer  ...
# 1061          838           Gary Walton     Regular Air         Consumer  ...
# 1977         1530          Seth Sweeney  Delivery Truck         Consumer  ...
# 2387         1796        Carlos Johnson  Delivery Truck        Corporate  ...
#
#      State or Province              City Postal Code Order Date  Ship Date  \
# 2291    North Carolina          Gastonia       28052 2010-03-28 2010-03-28
# 2121       Mississippi       Hattiesburg       39401 2012-05-21 2012-05-21
# 3811        Washington        Des Moines       98198 2010-03-10 2010-03-14
# 2381          Illinois         Galesburg       61401 2010-01-06 2010-01-07
# 2660           Montana           Bozeman       59715 2010-10-17 2010-10-19
# 2664          Colorado           Durango       81301 2011-01-18 2011-01-19
# 3771             Idaho             Boise       83701 2011-09-12 2011-09-14
# 1061        California  Hacienda Heights       91745 2013-10-02 2013-10-03
# 1977        California      Palm Springs       92262 2012-07-07 2012-07-09
# 2387        California     San Francisco       94110 2013-03-23 2013-03-24
#
#             Profit Quantity ordered new    Sales  Order ID difference_date
# 2291 -16476.838000                   10  1486.34     85865          0 days
# 2121 -14369.123580                    3    81.31     90534          0 days
# 3811 -14140.701600                    1  6296.00     87317          4 days
# 2381 -13706.464000                    8  6968.90     87853          1 days
# 2660 -13562.637408                    1  6569.07     91277          2 days
# 2664 -10402.943916                    1  3460.11     88799          1 days
# 3771 -10263.659700                    2  9507.12     89498          2 days
# 1061  -9078.940000                    2  6849.48     89896          1 days
# 1977  -8570.448300                    1  3057.44     88853          2 days
# 2387  -7961.430900                    1  3360.30     90778          1 days
#
# [10 rows x 26 columns]

# %%
(orders.sort_values('Profit', ascending = True)).reset_index().iloc[[9]]
# Out:
#    index  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 9   4857   24251           High      0.05     3502.14           8.73
#
#    Customer ID   Customer Name       Ship Mode Customer Segment  ...  \
# 9         1796  Carlos Johnson  Delivery Truck        Corporate  ...
#
#   State or Province           City Postal Code Order Date  Ship Date  \
# 9        California  San Francisco       94110 2013-03-23 2013-03-24
#
#       Profit Quantity ordered new   Sales  Order ID difference_date
# 9 -7961.4309                    1  3360.3     90778          1 days
#
# [1 rows x 26 columns]

# %%
#16. Try to find out 10 top  product with highest margins 
orders.sort_values(['Product Base Margin'])['Product Name'].head(10)
# Out:
# 2431              GBC DocuBind 200 Manual Binding Machine
# 8248       Peel & Seel® Recycled Catalog Envelopes, Brown
# 1515       Peel & Seel® Recycled Catalog Envelopes, Brown
# 5050       Peel & Seel® Recycled Catalog Envelopes, Brown
# 413                                           Accessory31
# 5034                          Prang Dustless Chalk Sticks
# 8308         Staples Brown Kraft Recycled Clasp Envelopes
# 8311     Storex DuraTech Recycled Plastic Frosted Binders
# 8318                                          Accessory31
# 1553    Adams Telephone Message Book w/Frequently-Call...
# Name: Product Name, dtype: object
